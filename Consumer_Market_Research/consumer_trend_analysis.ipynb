# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_squared_error

cs = pd.read_csv("ct.csv")
cs = cs.dropna()
 
columnNames = list(cs.columns.values.tolist())

regressionScoreList = {}

for index in range(1,len(cs.columns),1):
    X_axis = pd.to_datetime(cs.iloc[0:25,0]).dt.year
    Y_axis = cs.iloc[0:25,index]
    
    RLX_Axis = np.array(cs.iloc[0:25,index]).reshape(-1,1)
    RLY_Axis = np.array(cs.iloc[0:25,0])
    
    regModel = LinearRegression().fit(RLX_Axis,RLY_Axis)
    regressionScore = ("Linear regression: score " + str(round(regModel.score(RLX_Axis,RLY_Axis),3)))
    
    if (regModel.score(RLX_Axis,RLY_Axis) > 0.9) and (columnNames[index].find("£") != -1) and (columnNames[index].find("Total") == -1):
        regressionScoreList.update({columnNames[index]:regModel.score(RLX_Axis,RLY_Axis)})
        line1, = plt.plot(X_axis,Y_axis,'ro',linewidth=1,markersize=3,linestyle="solid")
        line2, = plt.plot(regModel.predict(RLX_Axis),Y_axis,linestyle="solid",color="blue")
        plt.title(columnNames[index])
        plt.legend([line1,line2],['Financials £ millions',regressionScore])
        plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

cs = pd.read_csv("ct.csv")
cs = cs.dropna()
 
columnNames = list(cs.columns.values.tolist())

regressionScoreList = {}

for index in range(1,len(cs.columns),1):
    RLX_Axis = np.array(cs.iloc[0:25,index]).reshape(-1,1)
    RLY_Axis = np.array(cs.iloc[0:25,0])
    
    regModel = LinearRegression().fit(RLX_Axis,RLY_Axis)
    regressionScore = ("Linear regression: score " + str(round(regModel.score(RLX_Axis,RLY_Axis),3)))
    
    if (regModel.score(RLX_Axis,RLY_Axis) > 0.9) and (columnNames[index].find("£") != -1) and (columnNames[index].find("Total") == -1):
       regressionScoreList.update({columnNames[index]:regModel.score(RLX_Axis,RLY_Axis)})

sector = []
for key, value in regressionScoreList.items():
   if key.find("£") != -1:
      print(key," pearson regression coefficient: ",round(value,3))
# Out:
# 04.1 Actual rentals for housing CP SA £m  pearson regression coefficient:  0.976
# 04 Housing; water; electricity; gas and other fuels CVM NAYear SA £m  pearson regression coefficient:  0.99
# 04.1 Actual rentals for housing CVM NAYear SA £m  pearson regression coefficient:  0.961
# 04.4 Water supply and miscellaneous services CP SA £m  pearson regression coefficient:  0.983
# 06 Health CP SA £m  pearson regression coefficient:  0.909
# 06.1 Medical products CP SA £m  pearson regression coefficient:  0.904
# 03.1.3 Clothing Other articles of clothing & clothing accessories CVM NAYear SA £m  pearson regression coefficient:  0.94
# 03.1.2 Clothing Garments CP SA £m  pearson regression coefficient:  0.921
# 03.2 Footwear CP SA £m  pearson regression coefficient:  0.904
# 04 Housing; water; electricity; gas and other fuels CP SA £m  pearson regression coefficient:  0.995
# 03.2 Footwear CVM NAYear SA £m  pearson regression coefficient:  0.942
# ...
